# %%
import pandas as pd

# %% [markdown]
# ## Extraction data from csv file

# %%
def extract_data():
    try:
        data = pd.read_csv("airflight.csv")
        print("successfull.....")
        return data
    except Exception as e:
        print(f'error in extracting data {e}')
        return None

df =extract_data()
# Out:
# successfull.....
